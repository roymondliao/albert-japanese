# %% [markdown]
# ## Wiki Extractor
# ```
# python -m wikiextractor.WikiExtractor --output ~/gogolook/data/jp_sms_project/pretraining_data/jp_wiki --json --namespaces 0 --no-templates ~/gogolook/data/jp_sms_project/pretraining_data/jp_wiki/jawiki-20191201-pages-articles-multistream.xml.bz2
# ```

# %%
import os
import json
from pathlib import Path

# %%
data_main_path = Path("/home/jupyter/gogolook/data/jp_sms_project/pretraining_data/jp_wiki")
test_data_path = data_main_path / 'AA' / 'wiki_00'

# %%
with open(str(test_data_path), 'rb') as f:
      a = f.readlines()

# %%
json.loads(a[2].decode('utf-8'))
# Out:
# {'id': '11',
#  'revid': '365037',
#  'url': 'https://ja.wikipedia.org/wiki?curid=11',
#  'title': '日本語',
# ...
